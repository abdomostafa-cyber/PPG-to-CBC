# %%
# import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import os
# from scipy.signal import spectrogram
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, Subset

from torchvision.models import resnet50
from tqdm.notebook import tqdm
# import io
# import zipfile
# from google.oauth2 import service_account
# from googleapiclient.discovery import build
# from googleapiclient.http import MediaIoBaseDownload

#Import my functions
import nbimporter
from Functions import MyDataset, download_dataset, train, validate, plot_loss_accuracy


# %matplotlib inline

# %%
dtypes = {str(i): 'float64' for i in range(5000)}
dtypes.update({
    'Segment_Time': 'str',
    'lab_flag': 'int',
    'Gender': 'str',
    'Age': 'float64',
})

# %%
repo_location = 'D:/simedy' # Change this to the location of the repository on your machine

test = 'Eosinophils'
panel = 'CBC'
time = '15 min'
gender_age_used = "No_GA"
file_path = os.path.join(repo_location, f'CSVs/Alldata_{test}_{time}.csv')

#if path does not exist, download the dataset
if not os.path.exists(file_path):
    download_dataset(repo_location)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
num_epochs = 50
batch_size = 128

# %%
df = pd.read_csv(file_path, dtype=dtypes)
if gender_age_used == "No_GA":
    df = df.drop(columns=['Gender', 'Age'])
if 'SubjectID' in df.columns:
    df = df.drop(columns=['SubjectID'])
df.lab_flag.hist();

# %%
# Assuming df is your DataFrame and 'label' is the column with the class labels
df_majority = df[df.lab_flag == df.lab_flag.value_counts().index[0]]  # Replace 0 with the actual majority class label
df_minority = df[df.lab_flag == df.lab_flag.value_counts().index[1]]  # Replace 1 with the actual minority class label

# If the majority class is at least 5 times the size of the minority class
if len(df_majority) / len(df_minority) >= 5:
    # Downsample majority class
    df_majority_downsampled = df_majority.sample(n=int(len(df_minority)*5), random_state=42)

    # Combine minority class with downsampled majority class
    df = pd.concat([df_majority_downsampled, df_minority])
    print(f"Resampled dataset shape: {df.lab_flag.value_counts()}")
# Out:
# Original dataset shape: lab_flag
# 0    4385
# 1     877
# Name: count, dtype: int64
# Resampled dataset shape: lab_flag
# 0    4385
# 1     877
# Name: count, dtype: int64

# %%
#Create a results folder
if not os.path.exists(os.path.join(repo_location, "Notebooks/", panel, "results")):
    os.makedirs(os.path.join(repo_location, "Notebooks/", panel, "results")) 
#Create a plots folder
if not os.path.exists(os.path.join(repo_location, "Notebooks/", panel, "plots")):
    os.makedirs(os.path.join(repo_location, "Notebooks/", panel, "plots"))

# %%
class ResNet50(nn.Module):
    def __init__(self, num_classes=2):
        super(ResNet50, self).__init__()
        self.resnet = resnet50(weights=None)
        self.resnet.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)
        self.resnet.fc = nn.Linear(2048, num_classes)
        self.dropout = nn.Dropout(p=0.2, inplace=False)

    def forward(self, x):
        x = self.resnet.conv1(x)
        x = self.resnet.bn1(x)
        x = self.resnet.relu(x)
        x = self.resnet.maxpool(x)

        x = self.resnet.layer1(x)
        x = self.resnet.layer2(x)
        x = self.resnet.layer3(x)
        x = self.resnet.layer4(x)

        x = F.adaptive_avg_pool2d(x, (1, 1))
        x = torch.flatten(x, 1)
        x = self.dropout(x)
        x = self.resnet.fc(x)
        x = F.softmax(x, dim=1)

        return x
    

class ResNet50_age_gender(nn.Module):
    def __init__(self, num_classes=2):
        super(ResNet50_age_gender, self).__init__()
        self.resnet = resnet50(weights=None)
        self.resnet.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)
        self.resnet.fc = nn.Identity()  # Remove the original fully connected layer
        self.dropout = nn.Dropout(p=0.2, inplace=False)
        self.fc = nn.Linear(2048 + 2, num_classes)  # 2048 for ResNet50 features + 2 for age and gender

    def forward(self, x_img, age, gender):
        # Process image data through ResNet50
        x = self.resnet.conv1(x_img)
        x = self.resnet.bn1(x)
        x = self.resnet.relu(x)
        x = self.resnet.maxpool(x)

        x = self.resnet.layer1(x)
        x = self.resnet.layer2(x)
        x = self.resnet.layer3(x)
        x = self.resnet.layer4(x)

        x = F.adaptive_avg_pool2d(x, (1, 1))
        x = torch.flatten(x, 1)
        x = self.dropout(x)

        # Combine image features with age and gender
        age_gender = torch.cat((age.unsqueeze(1), gender.unsqueeze(1)), dim=1)  # Shape: (batch_size, 2)
        combined = torch.cat((x, age_gender), dim=1)  # Shape: (batch_size, 2048 + 2)

        # Pass combined features through the final classification layer
        output = self.fc(combined)
        output = F.softmax(output, dim=1)

        return output

# %%
class_counts = df.lab_flag.value_counts().to_numpy()
total_samples = class_counts.sum()
class_weights = total_samples / (class_counts.shape[0] * class_counts)
if class_weights.max()/class_weights.min() <= 2:
    criterion = nn.CrossEntropyLoss()
else:
    class_weights_tensor = torch.tensor(class_weights, dtype=torch.float32).to(device)
    if df.lab_flag.value_counts().index[0] == 1:
        class_weights_tensor = class_weights_tensor.flip(0)
    criterion = nn.CrossEntropyLoss(weight = class_weights_tensor)
    print(df.lab_flag.value_counts())
    print(class_weights_tensor)

# %%
# Assuming `dataset` is your PyTorch dataset
# dataset = YourDatasetClass()
dataset = MyDataset(df)

# Step 1: Split the dataset indices
dataset_size = len(dataset)
indices = list(range(dataset_size))

# First split: train and temporary (which will be further split into validation and test)
train_indices, temp_indices = train_test_split(indices, test_size=0.4, random_state=42)

# Second split: validation and test (split the temporary set into validation and test)
val_indices, test_indices = train_test_split(temp_indices, test_size=0.5, random_state=42)

# Step 2: Create subsets
train_dataset = Subset(dataset, train_indices)
val_dataset = Subset(dataset, val_indices)
test_dataset = Subset(dataset, test_indices)

# Step 3: Create data loaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
if gender_age_used == "No_GA":
    model = ResNet50(num_classes = 2)
else:
    model = ResNet50_age_gender(num_classes = 2)
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)
best_val_acc = 0
train_loss, train_acc, val_loss, val_acc = [], [], [], []
scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda epoch: 0.95 ** epoch)

# %%
results_df = pd.DataFrame()
best_val_acc = 0
with tqdm(total=num_epochs) as pbar:    
    for epoch in range(1, int(num_epochs + 1)):
        
        train_loss, train_acc = train(model, train_loader, optimizer, criterion,
        epoch, device, gender_age_used, scheduler=scheduler)
        
        val_loss, val_acc, best_val_acc = validate(model, val_loader,
        criterion, best_val_acc, device, test, repo_location, gender_age_used)

        results_dict = {
            'train_loss': train_loss,
            'train_acc': train_acc,
            'val_loss': val_loss,
            'val_acc': val_acc
        }

        pbar.set_description(f"{test} Epoch {epoch}/{num_epochs} - Train Loss: {train_loss:.2f} - Train Acc: {train_acc*100:.2f} - Val Loss: {val_loss:.2f} - Val Acc: {val_acc*100:.2f}")
        results_df = pd.concat([results_df, pd.DataFrame([results_dict])], ignore_index=True)
        pbar.update(1)

plot_loss_accuracy(results_df.train_loss, results_df.train_acc, results_df.val_loss, results_df.val_acc, test, gender_age_used)
results_df.to_csv(os.path.join(repo_location, f"results/{test}_{gender_age_used}.csv"), index=False)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 6
#       3 with tqdm(total=num_epochs) as pbar:
#       4     for epoch in range(1, int(num_epochs + 1)):
# ----> 6         train_loss, train_acc = train(model, train_loader, optimizer, criterion,
#       7         epoch, device, gender_age_used, scheduler=scheduler)
#       9         val_loss, val_acc, best_val_acc = validate(model, val_loader,
#      10         criterion, best_val_acc, device, test, repo_location, gender_age_used)
#      12         results_dict = {
#      13             'train_loss': train_loss,
#      14             'train_acc': train_acc,
#      15             'val_loss': val_loss,
#      16             'val_acc': val_acc
#      17         }
#
# File d:\simedy\Notebooks\CBC\Functions.ipynb:24, in train(model, trainloader, optim, criterion, epoch, device, gender_age_used, scheduler)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 6,
#       6    "metadata": {},
#       7    "outputs": [],
#       8    "source": [
#       9     "import matplotlib.pyplot as plt\n",
#      10     "import numpy as np\n",
#      11     "import pandas as pd\n",
#      12     "import torch\n",
#      13     "import torch.nn as nn\n",
#      14     "import torch.nn.functional as F\n",
#      15     "import pywt\n",
#      16     "import os\n",
#      17     "from scipy.signal import spectrogram\n",
#      18     "from sklearn.model_selection import train_test_split\n",
#      19     "from sklearn.preprocessing import MinMaxScaler, RobustScaler\n",
#      20     "from torch.utils.data import DataLoader, Dataset\n",
#      21     "from torchvision.models import resnet50\n",
#      22     "from tqdm.notebook import tqdm\n",
#      23     "import io\n",
# ---> 24     "import zipfile\n",
#      25     "from google.oauth2 import service_account\n",
#      26     "from googleapiclient.discovery import build\n",
#      27     "from googleapiclient.http import MediaIoBaseDownload\n",
#      28     "import h5py\n",
#      29     "\n",
#      30     "\n",
#      31     "%matplotlib inline"
#      32    ]
#      33   },
#      34   {
#      35    "cell_type": "code",
#      36    "execution_count": 2,
#      37    "metadata": {},
#      38    "outputs": [],
#      39    "source": [
#      40     "def download_dataset(repo_location):\n",
#      41     "    # Path to the service account key file\n",
#      42     "    SERVICE_ACCOUNT_FILE = os.path.join(repo_location, 'ppg-ml-427113-ecc7e656b7f5.json')\n",
#      43     "\n",
#      44     "    # Define the required scopes\n",
#      45     "    SCOPES = ['https://www.googleapis.com/auth/drive.readonly']\n",
#      46     "\n",
#      47     "    # Authenticate using the service account\n",
#      48     "    credentials = service_account.Credentials.from_service_account_file(\n",
#      49     "        SERVICE_ACCOUNT_FILE, scopes=SCOPES)\n",
#      50     "\n",
#      51     "    # Build the Drive API client\n",
#      52     "    service = build('drive', 'v3', credentials=credentials)\n",
#      53     "\n",
#      54     "    # File ID of the .zip file to download\n",
#      55     "    file_id = '1uMejT3pEJVFKM20bzpsbS35NJSuG85DL'\n",
#      56     "\n",
#      57     "    # Request to download the .zip file\n",
#      58     "    request = service.files().get_media(fileId=file_id)\n",
#      59     "    zip_file_path = 'MIMIC CSVs.zip'\n",
#      60     "\n",
#      61     "    with io.FileIO(zip_file_path, 'wb') as fh:\n",
#      62     "        downloader = MediaIoBaseDownload(fh, request)\n",
#      63     "\n",
#      64     "        done = False\n",
#      65     "        while not done:\n",
#      66     "            status, done = downloader.next_chunk()\n",
#      67     "            print(f\"Download {int(status.progress() * 100)}%.\")\n",
#      68     "\n",
#      69     "    # Extract the downloaded .zip file\n",
#      70     "    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:\n",
#      71     "        zip_ref.extractall(os.path.join(repo_location, \"CSVs\"))  # Specify the directory to extract to\n",
#      72     "\n",
#      73     "    #Delete the zip file\n",
#      74     "    os.remove(zip_file_path)\n",
#      75     "    print(\"File downloaded and extracted successfully.\")"
#      76    ]
#      77   },
#      78   {
#      79    "cell_type": "code",
#      80    "execution_count": 5,
#      81    "metadata": {},
#      82    "outputs": [],
#      83    "source": [
#      84     "def load_h5_file(file_path):\n",
#      85     "    def recursively_load_data(h5_obj):\n",
#      86     "        if isinstance(h5_obj, h5py.Dataset):\n",
#      87     "            data = h5_obj[()]\n",
#      88     "            if isinstance(data, bytes):  # Decode byte strings\n",
#      89     "                return data.decode()\n",
#      90     "            elif isinstance(data, np.ndarray) and data.dtype.type is np.bytes_:\n",
#      91     "                return data.astype(str)  # Decode byte strings in numpy arrays\n",
#      92     "            return data\n",
#      93     "        elif isinstance(h5_obj, h5py.Group):\n",
#      94     "            data = {}\n",
#      95     "            for key, item in h5_obj.items():\n",
#      96     "                data[key] = recursively_load_data(item)\n",
#      97     "            return data\n",
#      98     "        else:\n",
#      99     "            raise TypeError(f\"Unsupported type: {type(h5_obj)}\")\n",
#     100     "\n",
#     101     "    with h5py.File(file_path, 'r') as f:\n",
#     102     "        return recursively_load_data(f)"
#     103    ]
#     104   },
#     105   {
#     106    "cell_type": "code",
#     107    "execution_count": null,
#     108    "metadata": {},
#     109    "outputs": [],
#     110    "source": [
#     111     "def safe_to_datetime(date_str):\n",
#     112     "    try:\n",
#     113     "        return pd.to_datetime(date_str, format='%Y-%m-%d-%H-%M-%S')\n",
#     114     "    except Exception as e:\n",
#     115     "        print(f\"Error parsing date '{date_str}': {e}\")\n",
#     116     "        return pd.NaT\n",
#     117     "\n",
#     118     "def process_file(path, file, subject_id, interval, labs_filtered):\n",
#     119     "    data = load_h5_file(os.path.join(path, file))\n",
#     120     "\n",
#     121     "    if ('Segment_Time') in data['Subj_Wins'].keys():\n",
#     122     "\n",
#     123     "        # Convert the data file into a dataframe \n",
#     124     "        df_data = pd.DataFrame(data['Subj_Wins']['PPG_Raw'].squeeze())\n",
#     125     "\n",
#     126     "        # Insert the Segment Time variable to the dataframe\n",
#     127     "        df_data.insert(0, 'Segment_Time', data['Subj_Wins']['Segment_Time'])\n",
#     128     "\n",
#     129     "        # Insert lab_flag variable to the dataframe. All values are equal to nan for now\n",
#     130     "        df_data.insert(1, 'lab_flag', np.nan)\n",
#     131     "\n",
#     132     "\n",
#     133     "        # Insert SubjectID, Age and gender variables to the dataframe\n",
#     134     "        df_data.insert(1, 'SubjectID', subject_id)\n",
#     135     "        df_data.insert(2, 'Age', data['Subj_Wins']['Age'])\n",
#     136     "        df_data.insert(3, 'Gender', data['Subj_Wins']['Gender'])\n",
#     137     "\n",
#     138     "        #Normalize the age variable by 130 to get a value between 0 and 1\n",
#     139     "        df_data['Age'] = df_data['Age']/130\n",
#     140     "\n",
#     141     "        # Convert numpy.str_ to native Python strings and convert to datetime\n",
#     142     "        df_data['Segment_Time'] = df_data['Segment_Time'].apply(lambda x: x[0] if isinstance(x, np.ndarray) else x).astype(str)\n",
#     143     "        df_data['Segment_Time'] = df_data['Segment_Time'].apply(safe_to_datetime)\n",
#     144     "                \n",
#     145     "        mask = (labs_filtered.SUBJECT_ID == subject_id)\n",
#     146     "        labs_filtered = labs_filtered[mask].reset_index(drop=True)\n",
#     147     "        \n",
#     148     "        matching_labs_indices = set()\n",
#     149     "        matching_data_indices = set()\n",
#     150     "\n",
#     151     "        start_time = df_data.Segment_Time - interval\n",
#     152     "        end_time = df_data.Segment_Time + interval\n",
#     153     "\n",
#     154     "        for i, row in df_data.iterrows():\n",
#     155     "            matching_labs_indices.update(\n",
#     156     "                labs_filtered[(labs_filtered.CHARTTIME >= start_time[i]) & (labs_filtered.CHARTTIME <= end_time[i])].index\n",
#     157     "            )\n",
#     158     "\n",
#     159     "        lab_start_time = labs_filtered.CHARTTIME - interval\n",
#     160     "        lab_end_time = labs_filtered.CHARTTIME + interval\n",
#     161     "\n",
#     162     "        for i, row in labs_filtered.iterrows():\n",
#     163     "            matching_data_indices.update(\n",
#     164     "                df_data[(df_data.Segment_Time >= lab_start_time[i]) & (df_data.Segment_Time <= lab_end_time[i])].index\n",
#     165     "            )\n",
#     166     "\n",
#     167     "        # Convert sets to lists for indexing\n",
#     168     "        matching_labs_indices = list(matching_labs_indices)\n",
#     169     "        matching_data_indices = list(matching_data_indices)\n",
#     170     "\n",
#     171     "        df_data = df_data.loc[matching_data_indices].reset_index(drop=True)\n",
#     172     "        labs_filtered = labs_filtered.loc[matching_labs_indices].reset_index(drop=True)\n",
#     173     "\n",
#     174     "        start_time = df_data.Segment_Time - interval\n",
#     175     "        end_time = df_data.Segment_Time + interval\n",
#     176     "\n",
#     177     "        # Vectorize the process of creating lab flags\n",
#     178     "        for i in range(len(df_data)):\n",
#     179     "            labs_subset = labs_filtered[\n",
#     180     "                (labs_filtered.CHARTTIME >= start_time[i]) &\n",
#     181     "                (labs_filtered.CHARTTIME <= end_time[i])\n",
#     182     "            ]\n",
#     183     "            if labs_subset.shape[0] > 0:\n",
#     184     "                flag_sum = labs_subset.FLAG.sum()\n",
#     185     "                df_data.loc[i, 'lab_flag'] = 1 if flag_sum > 0 else 0 if flag_sum == 0 else np.nan\n",
#     186     "\n",
#     187     "            # Check if we have reached 100 samples for either flag, and filter out the other flag once it happens\n",
#     188     "            if df_data[df_data.lab_flag == 0].shape[0] == 100:\n",
#     189     "                labs_subset = labs_subset[labs_subset.FLAG == 1]\n",
#     190     "            if df_data[df_data.lab_flag == 1].shape[0] == 100:\n",
#     191     "                labs_subset = labs_subset[labs_subset.FLAG == 0]\n",
#     192     "        \n",
#     193     "        return df_data.dropna()"
#     194    ]
#     195   },
#     196   {
#     197    "cell_type": "code",
#     198    "execution_count": null,
#     199    "metadata": {},
#     200    "outputs": [],
#     201    "source": [
#     202     "def process_file_optimized(path, file, subject_id, interval, labs_filtered):\n",
#     203     "    data = load_h5_file(os.path.join(path, file))\n",
#     204     "\n",
#     205     "    if ('Segment_Time') in data['Subj_Wins'].keys():\n",
#     206     "\n",
#     207     "        # Convert the data file into a dataframe \n",
#     208     "        df_data = pd.DataFrame(data['Subj_Wins']['PPG_Raw'].squeeze())\n",
#     209     "\n",
#     210     "        # Insert the Segment Time variable to the dataframe\n",
#     211     "        df_data.insert(0, 'Segment_Time', data['Subj_Wins']['Segment_Time'])\n",
#     212     "\n",
#     213     "        # Insert lab_flag variable to the dataframe. All values are equal to nan for now\n",
#     214     "        df_data.insert(1, 'lab_flag', np.nan)\n",
#     215     "\n",
#     216     "        # Insert SubjectID, Age and Gender variables to the dataframe\n",
#     217     "        df_data.insert(1, 'SubjectID', subject_id)\n",
#     218     "        df_data.insert(2, 'Age', data['Subj_Wins']['Age'])\n",
#     219     "        df_data.insert(3, 'Gender', data['Subj_Wins']['Gender'])\n",
#     220     "\n",
#     221     "        # Normalize the age variable by 130 to get a value between 0 and 1\n",
#     222     "        df_data['Age'] = df_data['Age']/130\n",
#     223     "\n",
#     224     "        # Convert numpy.str_ to native Python strings and convert to datetime\n",
#     225     "        df_data['Segment_Time'] = df_data['Segment_Time'].apply(lambda x: x[0] if isinstance(x, np.ndarray) else x).astype(str)\n",
#     226     "        df_data['Segment_Time'] = df_data['Segment_Time'].apply(safe_to_datetime)\n",
#     227     "   \n",
#     228     "        # Filter labs_filtered for the specific subject\n",
#     229     "        labs_filtered = labs_filtered[labs_filtered.SUBJECT_ID == subject_id]\n",
#     230     "\n",
#     231     "        # Create time windows\n",
#     232     "        df_data['start_time'] = df_data['Segment_Time'] - interval\n",
#     233     "        df_data['end_time'] = df_data['Segment_Time'] + interval\n",
#     234     "\n",
#     235     "        labs_filtered['start_time'] = labs_filtered['CHARTTIME'] - interval\n",
#     236     "        labs_filtered['end_time'] = labs_filtered['CHARTTIME'] + interval\n",
#     237     "\n",
#     238     "        # Merge df_data and labs_filtered based on time windows\n",
#     239     "        merged = pd.merge_asof(df_data.sort_values('Segment_Time'), \n",
#     240     "                            labs_filtered.sort_values('CHARTTIME'), \n",
#     241     "                            left_on='Segment_Time', right_on='CHARTTIME', \n",
#     242     "                            direction='nearest', tolerance=interval)\n",
#     243     "        \n",
#     244     "        # Assign lab_flag based on FLAG\n",
#     245     "        merged['lab_flag'] = np.where(merged['FLAG'].notna(), merged['FLAG'], np.nan)\n",
#     246     "\n",
#     247     "        # Drop unnecessary columns\n",
#     248     "        merged.drop(columns=['start_time_y', 'end_time_y', 'CHARTTIME', 'SUBJECT_ID',\n",
#     249     "                             'FLAG', 'start_time_x', 'end_time_x', 'HADM_ID', 'ROW_ID',\n",
#     250     "                             'ITEMID', 'VALUE', 'VALUENUM', 'VALUEUOM', 'Panel', 'Subpanel'], inplace=True)\n",
#     251     "\n",
#     252     "        return merged.dropna().reset_index(drop=True)"
#     253    ]
#     254   },
#     255   {
#     256    "cell_type": "code",
#     257    "execution_count": null,
#     258    "metadata": {},
#     259    "outputs": [],
#     260    "source": [
#     261     "class MyDataset(Dataset):\n",
#     262     "\n",
#     263     "    def __init__(self, df):\n",
#     264     "        self.df = df\n",
#     265     "        self.y_data = df.lab_flag.values\n",
#     266     "        self.X_data = df.loc[:, df.columns.intersection([str(i) for i in range(0, 1250)])]\n",
#     267     "        if ('Age' in self.df.columns) and ('Gender' in self.df.columns):\n",
#     268     "            self.age_data = df.Age.values\n",
#     269     "            # Change gender values from 'M' and 'F' to 0 and 1\n",
#     270     "            self.gender_data = df.Gender.map({'M': 0, 'F': 1}).values\n",
#     271     "\n",
#     272     "    \n",
#     273     "    def __len__(self):\n",
#     274     "        return len(self.X_data)\n",
#     275     "\n",
#     276     "    def __getitem__(self, idx):\n",
#     277     "        row = self.X_data.iloc[idx]\n",
#     278     "        _, _, spec = spectrogram(row.values.astype(np.float32), fs=125, nperseg=256)\n",
#     279     "        y = self.y_data[idx]\n",
#     280     "        if ('Age' in self.df.columns) and ('Gender' in self.df.columns):\n",
#     281     "            age = torch.tensor(self.age_data[idx], dtype=torch.float32)\n",
#     282     "            gender = torch.tensor(self.gender_data[idx], dtype=torch.float32)\n",
#     283     "            X = torch.tensor(spec, dtype=torch.float32).unsqueeze(0)  # Add channel dimension for grayscale image\n",
#     284     "            return X, age, gender, y\n",
#     285     "        else:\n",
#     286     "            X = torch.tensor(spec, dtype=torch.float32)\n",
#     287     "            return X, y  "
#     288    ]
#     289   },
#     290   {
#     291    "cell_type": "code",
#     292    "execution_count": null,
#     293    "metadata": {},
#     294    "outputs": [],
#     295    "source": [
#     296     "class MyWaveletDataset(Dataset):\n",
#     297     "    def __init__(self, df):\n",
#     298     "        self.df = df\n",
#     299     "        self.y_data = df.lab_flag.values\n",
#     300     "        self.X_data = df.loc[:, df.columns.intersection([str(i) for i in range(0, 1250)])]\n",
#     301     "        if ('Age' in self.df.columns) and ('Gender' in self.df.columns):\n",
#     302     "            self.age_data = df.Age.values\n",
#     303     "            # Change gender values from 'M' and 'F' to 0 and 1\n",
#     304     "            self.gender_data = df.Gender.map({'M': 0, 'F': 1}).values\n",
#     305     "\n",
#     306     "    def __len__(self):\n",
#     307     "        return len(self.X_data)\n",
#     308     "\n",
#     309     "    def __getitem__(self, idx):\n",
#     310     "        row = self.X_data.iloc[idx]\n",
#     311     "        signal = row.values.astype(np.float32)\n",
#     312     "\n",
#     313     "        # Perform Discrete Wavelet Transform\n",
#     314     "        coeffs = pywt.wavedec(signal, 'db4', level=4)\n",
#     315     "        coeffs_array = np.concatenate(coeffs)\n",
#     316     "\n",
#     317     "        y = self.y_data[idx]\n",
#     318     "        if ('Age' in self.df.columns) and ('Gender' in self.df.columns):\n",
#     319     "            age = torch.tensor(self.age_data[idx], dtype=torch.float32)\n",
#     320     "            gender = torch.tensor(self.gender_data[idx], dtype=torch.float32)\n",
#     321     "            X = torch.tensor(coeffs_array, dtype=torch.float32).unsqueeze(0).unsqueeze(0)  # Add channel dimension if needed\n",
#     322     "            return X, age, gender, y\n",
#     323     "        else:\n",
#     324     "            X = torch.tensor(coeffs_array, dtype=torch.float32).unsqueeze(0)\n",
#     325     "            return X, y"
#     326    ]
#     327   },
#     328   {
#     329    "cell_type": "code",
#     330    "execution_count": 2,
#     331    "metadata": {},
#     332    "outputs": [],
#     333    "source": [
#     334     "def train(model, trainloader, optim, criterion, epoch, device, gender_age_used, scheduler=None):\n",
#     335     "    model.train()\n",
#     336     "    running_loss = 0.0\n",
#     337     "    correct = 0\n",
#     338     "    total = 0\n",
#     339     "\n",
#     340     "    for data in trainloader:\n",
#     341     "        if gender_age_used == \"GA_used\":\n",
#     342     "            inputs, age, gender, labels = data\n",
#     343     "            inputs, age, gender, labels = inputs.to(device), age.to(device), gender.to(device), labels.to(device)\n",
#     344     "            labels = labels.long()  # Convert labels to Long type\n",
#     345     "            optim.zero_grad()\n",
#     346     "            outputs = model(inputs, age, gender)\n",
#     347     "        else:\n",
#     348     "            inputs, labels = data\n",
#     349     "            inputs, labels = inputs.to(device), labels.to(device)\n",
#     350     "            labels = labels.long()\n",
#     351     "            optim.zero_grad()\n",
#     352     "            outputs = model(inputs.unsqueeze(1))\n",
#     353     "        # print(inputs.shape)\n",
#     354     "        # print(outputs.shape, labels)\n",
#     355     "        loss = criterion(outputs, labels)\n",
#     356     "        loss.backward()\n",
#     357     "        optim.step()\n",
#     358     "\n",
#     359     "        running_loss += loss.item()\n",
#     360     "\n",
#     361     "        _, predicted = torch.max(outputs.data, 1)\n",
#     362     "        total += labels.size(0)\n",
#     363     "        correct += (predicted == labels).sum().item()\n",
#     364     "\n",
#     365     "    train_loss = running_loss / len(trainloader)\n",
#     366     "    train_acc = correct / total\n",
#     367     "    if scheduler:\n",
#     368     "        scheduler.step()\n",
#     369     "    # print(f\"Epoch {epoch} loss: {train_loss}\")\n",
#     370     "    # print(f\"Epoch {epoch} accuracy: {train_acc}\")\n",
#     371     "    \n",
#     372     "    return train_loss, train_acc\n",
#     373     "\n",
#     374     "\n",
#     375     "def validate(model, testloader, criterion, best_val_acc, device, test, repo_location, gender_age_used):\n",
#     376     "    model.eval()\n",
#     377     "    running_loss = 0.0\n",
#     378     "    correct = 0\n",
#     379     "    total = 0\n",
#     380     "\n",
#     381     "    with torch.no_grad():\n",
#     382     "        for data in testloader:\n",
#     383     "            \n",
#     384     "            if gender_age_used == \"GA_used\":\n",
#     385     "                inputs, age, gender, labels = data\n",
#     386     "                inputs, age, gender, labels = inputs.to(device), age.to(device), gender.to(device), labels.to(device)\n",
#     387     "                labels = labels.long()  # Convert labels to Long type\n",
#     388     "                outputs = model(inputs, age, gender)\n",
#     389     "            else:\n",
#     390     "                inputs, labels = data\n",
#     391     "                inputs, labels = inputs.to(device), labels.to(device)\n",
#     392     "                labels = labels.long()\n",
#     393     "                outputs = model(inputs.unsqueeze(1))\n",
#     394     "            loss = criterion(outputs, labels)\n",
#     395     "\n",
#     396     "            running_loss += loss.item()\n",
#     397     "\n",
#     398     "            _, predicted = torch.max(outputs.data, 1)\n",
#     399     "            total += labels.size(0)\n",
#     400     "            correct += (predicted == labels).sum().item()\n",
#     401     "\n",
#     402     "    val_loss = (running_loss / len(testloader))\n",
#     403     "    val_acc = (correct / total)      \n",
#     404     "\n",
#     405     "    # print(f\"Validation loss: {val_loss}\")\n",
#     406     "    # print(f\"Validation accuracy: {val_acc}\")\n",
#     407     "\n",
#     408     "    if correct / total > best_val_acc:\n",
#     409     "        best_val_acc = correct / total\n",
#     410     "        torch.save(model.state_dict(), os.path.join(repo_location, f\"models/bestmodel_{test}_{gender_age_used}.pth\"))\n",
#     411     "    return val_loss, val_acc, best_val_acc"
#     412    ]
#     413   },
#     414   {
#     415    "cell_type": "code",
#     416    "execution_count": 10,
#     417    "metadata": {},
#     418    "outputs": [],
#     419    "source": [
#     420     "def plot_loss_accuracy(train_loss, train_acc, validation_loss, validation_acc, test, gender_age_used=\"\"):\n",
#     421     "    epochs = len(train_loss)\n",
#     422     "    fig, (ax1, ax2) = plt.subplots(1, 2)\n",
#     423     "    ax1.plot(list(range(epochs)), train_loss, label='Training Loss')\n",
#     424     "    ax1.plot(list(range(epochs)), validation_loss, label='Validation Loss')\n",
#     425     "    ax1.set_xlabel('Epochs')\n",
#     426     "    ax1.set_ylabel('Loss')\n",
#     427     "    ax1.set_title(f'Epoch vs Loss for {test}')\n",
#     428     "    ax1.legend()\n",
#     429     "\n",
#     430     "    ax2.plot(list(range(epochs)), train_acc, label='Training Accuracy')\n",
#     431     "    ax2.plot(list(range(epochs)), validation_acc, label='Validation Accuracy')\n",
#     432     "    ax2.set_xlabel('Epochs')\n",
#     433     "    ax2.set_ylabel('Accuracy')\n",
#     434     "    ax2.set_title(f'Epoch vs Accuracy for {test}')\n",
#     435     "    ax2.legend()\n",
#     436     "    fig.set_size_inches(15.5, 5.5)\n",
#     437     "    fig.savefig(f\"plots/{test}{gender_age_used}.png\")"
#     438    ]
#     439   },
#     440   {
#     441    "cell_type": "code",
#     442    "execution_count": null,
#     443    "metadata": {},
#     444    "outputs": [],
#     445    "source": []
#     446   }
#     447  ],
#     448  "metadata": {
#     449   "kernelspec": {
#     450    "display_name": "simedy2",
#     451    "language": "python",
#     452    "name": "python3"
#     453   },
#     454   "language_info": {
#     455    "codemirror_mode": {
#     456     "name": "ipython",
#     457     "version": 3
#     458    },
#     459    "file_extension": ".py",
#     460    "mimetype": "text/x-python",
#     461    "name": "python",
#     462    "nbconvert_exporter": "python",
#     463    "pygments_lexer": "ipython3",
#     464    "version": "3.11.9"
#     465   }
#     466  },
#     467  "nbformat": 4,
#     468  "nbformat_minor": 2
#     469 }
#
# File c:\Users\Abdo\Anaconda3\envs\simedy2\Lib\site-packages\torch\optim\lr_scheduler.py:75, in LRScheduler.__init__.<locals>.with_counter.<locals>.wrapper(*args, **kwargs)
#      73 instance._step_count += 1
#      74 wrapped = func.__get__(instance, cls)
# ---> 75 return wrapped(*args, **kwargs)
#
# File c:\Users\Abdo\Anaconda3\envs\simedy2\Lib\site-packages\torch\optim\optimizer.py:379, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     377 self = cast(Optimizer, self)
#     378 profile_name = f"Optimizer.step#{self.__class__.__name__}.step"
# --> 379 with torch.autograd.profiler.record_function(profile_name):
#     380     # call optimizer step pre hooks
#     381     for pre_hook in chain(_global_optimizer_pre_hooks.values(), self._optimizer_step_pre_hooks.values()):
#     382         result = pre_hook(self, args, kwargs)
#
# File c:\Users\Abdo\Anaconda3\envs\simedy2\Lib\site-packages\torch\autograd\profiler.py:605, in record_function.__enter__(self)
#     604 def __enter__(self):
# --> 605     self.record = torch.ops.profiler._record_function_enter_new(
#     606         self.name, self.args
#     607     )
#     608     return self
#
# File c:\Users\Abdo\Anaconda3\envs\simedy2\Lib\site-packages\torch\_ops.py:854, in OpOverloadPacket.__call__(self_, *args, **kwargs)
#     846 def __call__(self_, *args, **kwargs):  # noqa: B902
#     847     # use `self_` to avoid naming collide with aten ops arguments that
#     848     # named "self". This way, all the aten ops can be called by kwargs.
#    (...)
#     852     # We save the function ptr as the `op` attribute on
#     853     # OpOverloadPacket to access it here.
# --> 854     return self_._op(*args, **(kwargs or {}))
#
# KeyboardInterrupt:

# %%
from torchmetrics.classification import BinaryAUROC, BinaryAveragePrecision
#if csv results file does not exist, create one
if not os.path.exists(os.path.join(repo_location, "Notebooks", panel, f"results/{panel}_test_results.csv")):
    test_results = pd.DataFrame()
else:
    test_results = pd.read_csv(os.path.join(repo_location, "Notebooks", panel, f"results/{panel}_test_results.csv"))

#Load the best model
if gender_age_used == "No_GA":
    model = ResNet50(num_classes = 2)
else:
    model = ResNet50_age_gender(num_classes = 2)
model.load_state_dict(torch.load(os.path.join(repo_location, f"models/bestmodel_{test}_{gender_age_used}.pth")))
model.to(device)

model.eval()
#Create a confusion matrix
confusion_matrix = np.zeros((2, 2))
outputs = torch.tensor([]).to(device)
targets = torch.tensor([]).to(device)

#Iterate over the test data
with torch.no_grad():
    for i, data in enumerate(test_loader, 0):
        if gender_age_used == "GA_used":
            inputs, age, gender, labels = data
            inputs, age, gender, labels = inputs.to(device), age.to(device), gender.to(device), labels.to(device)
            labels = labels.long()  # Convert labels to Long type
            output = model(inputs, age, gender)
        else:
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            labels = labels.long()
            output = model(inputs.unsqueeze(1))
        

        _, predicted = torch.max(output.data, 1)
        outputs = torch.cat((outputs, predicted), 0)
        targets = torch.cat((targets, labels), 0)

        for j in range(len(predicted)):
            confusion_matrix[labels[j], predicted[j]] += 1

#Calculate the accuracy
accuracy = np.trace(confusion_matrix) / np.sum(confusion_matrix)

# Calculate precision and recall for class 1
if np.sum(confusion_matrix[:, 1]) == 0:
    precision = 0
else:
    precision = confusion_matrix[1, 1] / np.sum(confusion_matrix[:, 1])

if np.sum(confusion_matrix[1, :]) == 0:
    recall = 0
else:
    recall = confusion_matrix[1, 1] / np.sum(confusion_matrix[1, :])

# Calculate F1 score for class 1
if precision + recall == 0:
    f1 = 0
else:
    f1 = 2 * (precision * recall) / (precision + recall)

# Calculate specificity and NPV for class 0
if np.sum(confusion_matrix[0, :]) == 0:
    specificity = 0
else:
    specificity = confusion_matrix[0, 0] / np.sum(confusion_matrix[0, :])
if np.sum(confusion_matrix[:, 0]) == 0:
    npv = 0
else:     
    npv = confusion_matrix[0, 0] / np.sum(confusion_matrix[:, 0])

#Calculate auroc and auprc
auroc = BinaryAUROC()
auprc = BinaryAveragePrecision()


#Create a dictionary of the results
results_dict = {
    'test': test,
    'class_0_sample':df[df.lab_flag == 0].shape[0],
    'class_1_sample':df[df.lab_flag == 1].shape[0], 
    'accuracy': accuracy,
    'precision': precision,
    'recall': recall,
    'f1': f1,
    'specificity': specificity,
    'npv': npv,
    'auroc': auroc(outputs, targets.type(torch.int64)).item(),
    'auprc': auprc(outputs, targets.type(torch.int64)).item(),
    'interval': f"{int(time.split(' ')[0]) * 2} min",
    'Gender_age_used': gender_age_used,
    'notes': f'''''' 
}

#Append the results to the test_results dataframe
test_results = pd.concat([test_results, pd.DataFrame([results_dict])], ignore_index=True)

#Save the results to a csv file
test_results.to_csv(os.path.join(repo_location, "Notebooks", panel, f"results/{panel}_test_results.csv"), index=False)

# %%
results_dict
# Out:
# {'test': 'Eosinophils',
#  'accuracy': 0.9468085106382979,
#  'precision': 0.46511627906976744,
#  'recall': 0.6779661016949152,
#  'f1': 0.5517241379310345,
#  'specificity': 0.9604471195184867,
#  'npv': 0.983274647887324,
#  'interval': '30 min',
#  'Gender_age_used': 'No_GA',
#  'class_0_sample': 17452,
#  'class_1_sample': 877,
#  'notes': '\n'}

# %%
gender_age_used = "GA_used"
df = pd.read_csv(file_path, dtype=dtypes)
if gender_age_used == "No_GA":
    df = df.drop(columns=['Gender', 'Age'])
if 'SubjectID' in df.columns:
    df = df.drop(columns=['SubjectID'])
df.lab_flag.hist();

# %%
#Downsample the class with the majority of data
df_majority = df[df.lab_flag == df.lab_flag.value_counts().index[0]]  
df_minority = df[df.lab_flag == df.lab_flag.value_counts().index[1]]

# If the majority class is at least 5 times the size of the minority class
if len(df_majority) / len(df_minority) >= 5:
    # Downsample majority class
    df_majority_downsampled = df_majority.sample(n=int(len(df_minority)*5), random_state=42)

    # Combine minority class with downsampled majority class
    df = pd.concat([df_majority_downsampled, df_minority])
    print(f"Resampled dataset shape: {df.lab_flag.value_counts()}")
# Out:
# Resampled dataset shape: lab_flag
# 1    83305
# 0    16661
# Name: count, dtype: int64

# %%
class_counts = df.lab_flag.value_counts().to_numpy()
total_samples = class_counts.sum()
class_weights = total_samples / (class_counts.shape[0] * class_counts)
if class_weights.max()/class_weights.min() <= 2:
    criterion = nn.CrossEntropyLoss()
else:
    class_weights_tensor = torch.tensor(class_weights, dtype=torch.float32).to(device)
    if df.lab_flag.value_counts().index[0] == 1:
        class_weights_tensor = class_weights_tensor.flip(0)
    criterion = nn.CrossEntropyLoss(weight = class_weights_tensor)
    print(df.lab_flag.value_counts())
    print(class_weights_tensor)
# Out:
# lab_flag
# 0    17452
# 1      877
# Name: count, dtype: int64
# tensor([ 0.5251, 10.4498], device='cuda:0')

# %%
# Assuming `dataset` is your PyTorch dataset
# dataset = YourDatasetClass()
dataset = MyDataset(df)

# Step 1: Split the dataset indices
dataset_size = len(dataset)
indices = list(range(dataset_size))

# First split: train and temporary (which will be further split into validation and test)
train_indices, temp_indices = train_test_split(indices, test_size=0.4, random_state=42)

# Second split: validation and test (split the temporary set into validation and test)
val_indices, test_indices = train_test_split(temp_indices, test_size=0.5, random_state=42)

# Step 2: Create subsets
train_dataset = Subset(dataset, train_indices)
val_dataset = Subset(dataset, val_indices)
test_dataset = Subset(dataset, test_indices)

# Step 3: Create data loaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
if gender_age_used == "No_GA":
    model = ResNet50(num_classes = 2)
else:
    model = ResNet50_age_gender(num_classes = 2)
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)
best_val_acc = 0
train_loss, train_acc, val_loss, val_acc = [], [], [], []
scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda epoch: 0.95 ** epoch)

# %%
results_df = pd.DataFrame()
best_val_acc = 0
with tqdm(total=num_epochs) as pbar:    
    for epoch in range(1, int(num_epochs + 1)):
        
        train_loss, train_acc = train(model, train_loader, optimizer, criterion,
        epoch, device, gender_age_used, scheduler=scheduler)
        
        val_loss, val_acc, best_val_acc = validate(model, val_loader,
        criterion, best_val_acc, device, test, repo_location, gender_age_used)

        results_dict = {
            'train_loss': train_loss,
            'train_acc': train_acc,
            'val_loss': val_loss,
            'val_acc': val_acc
        }

        pbar.set_description(f"{test} Epoch {epoch}/{num_epochs} - Train Loss: {train_loss:.2f} - Train Acc: {train_acc*100:.2f} - Val Loss: {val_loss:.2f} - Val Acc: {val_acc*100:.2f}")
        results_df = pd.concat([results_df, pd.DataFrame([results_dict])], ignore_index=True)
        pbar.update(1)

plot_loss_accuracy(results_df.train_loss, results_df.train_acc, results_df.val_loss, results_df.val_acc, test, gender_age_used)
results_df.to_csv(os.path.join(repo_location, f"results/{test}_{gender_age_used}.csv"), index=False)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
from torchmetrics.classification import BinaryAUROC, BinaryAveragePrecision
#if csv results file does not exist, create one
if not os.path.exists(os.path.join(repo_location, "Notebooks", panel, f"results/{panel}_test_results.csv")):
    test_results = pd.DataFrame()
else:
    test_results = pd.read_csv(os.path.join(repo_location, "Notebooks", panel, f"results/{panel}_test_results.csv"))

#Load the best model
if gender_age_used == "No_GA":
    model = ResNet50(num_classes = 2)
else:
    model = ResNet50_age_gender(num_classes = 2)
model.load_state_dict(torch.load(os.path.join(repo_location, f"models/bestmodel_{test}_{gender_age_used}.pth")))
model.to(device)

model.eval()
#Create a confusion matrix
confusion_matrix = np.zeros((2, 2))
outputs = torch.tensor([]).to(device)
targets = torch.tensor([]).to(device)

#Iterate over the test data
with torch.no_grad():
    for i, data in enumerate(test_loader, 0):
        if gender_age_used == "GA_used":
            inputs, age, gender, labels = data
            inputs, age, gender, labels = inputs.to(device), age.to(device), gender.to(device), labels.to(device)
            labels = labels.long()  # Convert labels to Long type
            output = model(inputs, age, gender)
        else:
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            labels = labels.long()
            output = model(inputs.unsqueeze(1))
        

        _, predicted = torch.max(output.data, 1)
        outputs = torch.cat((outputs, predicted), 0)
        targets = torch.cat((targets, labels), 0)

        for j in range(len(predicted)):
            confusion_matrix[labels[j], predicted[j]] += 1

#Calculate the accuracy
accuracy = np.trace(confusion_matrix) / np.sum(confusion_matrix)

# Calculate precision and recall for class 1
if np.sum(confusion_matrix[:, 1]) == 0:
    precision = 0
else:
    precision = confusion_matrix[1, 1] / np.sum(confusion_matrix[:, 1])

if np.sum(confusion_matrix[1, :]) == 0:
    recall = 0
else:
    recall = confusion_matrix[1, 1] / np.sum(confusion_matrix[1, :])

# Calculate F1 score for class 1
if precision + recall == 0:
    f1 = 0
else:
    f1 = 2 * (precision * recall) / (precision + recall)

# Calculate specificity and NPV for class 0
if np.sum(confusion_matrix[0, :]) == 0:
    specificity = 0
else:
    specificity = confusion_matrix[0, 0] / np.sum(confusion_matrix[0, :])
if np.sum(confusion_matrix[:, 0]) == 0:
    npv = 0
else:     
    npv = confusion_matrix[0, 0] / np.sum(confusion_matrix[:, 0])

#Calculate auroc and auprc
auroc = BinaryAUROC()
auprc = BinaryAveragePrecision()


#Create a dictionary of the results
results_dict = {
    'test': test,
    'class_0_sample':df[df.lab_flag == 0].shape[0],
    'class_1_sample':df[df.lab_flag == 1].shape[0], 
    'accuracy': accuracy,
    'precision': precision,
    'recall': recall,
    'f1': f1,
    'specificity': specificity,
    'npv': npv,
    'auroc': auroc(outputs, targets.type(torch.int64)).item(),
    'auprc': auprc(outputs, targets.type(torch.int64)).item(),
    'interval': f"{int(time.split(' ')[0]) * 2} min",
    'Gender_age_used': gender_age_used,
    'notes': f'''''' 
}

#Append the results to the test_results dataframe
test_results = pd.concat([test_results, pd.DataFrame([results_dict])], ignore_index=True)

#Save the results to a csv file
test_results.to_csv(os.path.join(repo_location, "Notebooks", panel, f"results/{panel}_test_results.csv"), index=False)

# %%
results_dict
# Out:
# {'test': 'Eosinophils',
#  'accuracy': 0.9484451718494271,
#  'precision': 0.47413793103448276,
#  'recall': 0.6214689265536724,
#  'f1': 0.5378973105134474,
#  'specificity': 0.9650329607337346,
#  'npv': 0.9804892253931276,
#  'interval': '30 min',
#  'Gender_age_used': 'GA_used',
#  'class_0_sample': 17452,
#  'class_1_sample': 877,
#  'notes': '\n'}

# %%
# import shutil
# import os

# def duplicate_file_to_targets(source_file, target_files):
#     """
#     Replaces each target file with the contents of the source file while retaining the target file's name.

#     Args:
#         source_file (str): Path to the source file to duplicate.
#         target_files (list): List of paths to the target files to be replaced.
#     """
#     if not os.path.exists(source_file):
#         print(f"Source file '{source_file}' does not exist.")
#         return

#     for target_file in target_files:
#         try:
#             if os.path.exists(target_file):
#                 os.remove(target_file)  # Remove the existing target file
#             shutil.copy(source_file, target_file)  # Copy the source file to the target location
#             print(f"Copied '{source_file}' to '{target_file}'")
#         except Exception as e:
#             print(f"Failed to copy '{source_file}' to '{target_file}': {e}")

# # Example usage
# source_file = 'Basophils_resnet50.ipynb'  # Path to the source file
# target_files = [
#     r'D:\simedy\Notebooks\CBC\Hematocrit_resnet50.ipynb',
#     r'D:\simedy\Notebooks\CBC\Eosinophils_resnet50.ipynb',
#     r'D:\simedy\Notebooks\CBC\RDW_resnet50.ipynb',
#     r'D:\simedy\Notebooks\CBC\MCHC_resnet50.ipynb',
#     r'D:\simedy\Notebooks\CBC\MCH_resnet50.ipynb',
#     r'D:\simedy\Notebooks\CBC\MCV_resnet50.ipynb',
#     r'D:\simedy\Notebooks\CBC\Monocytes_resnet50.ipynb',
#     r'D:\simedy\Notebooks\CBC\Neutrophils_resnet50.ipynb',
#     r'D:\simedy\Notebooks\CBC\NRBCs_resnet50.ipynb',
#     r'D:\simedy\Notebooks\CBC\Platelets_resnet50.ipynb',
#     r'D:\simedy\Notebooks\CBC\RBCs_resnet50.ipynb',
#     r'D:\simedy\Notebooks\CBC\Lymphocytes_resnet50.ipynb',
#     r'D:\simedy\Notebooks\CBC\WBC_resnet50.ipynb',
#     r'D:\simedy\Notebooks\CBC\Hemoglobin_resnet50.ipynb'
#     # Add more target file paths as needed
# ]

# duplicate_file_to_targets(source_file, target_files)
